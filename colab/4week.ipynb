# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 공부시간 x와 성적 y의 리스트를 만들기
data = [[2, 81], [4, 93], [6, 91], [8, 97]]
x = [i[0] for i in data]
y = [i[1] for i in data]

#그래프로 나타내기
plt.figure(figsize=(8,5))
plt.scatter(x,y)
plt.show()

#리스트로 되어 있는 x와 y값을 넘파이 배열로 바꾸기(인덱스를 주어 하나씩 불러와 계산이 가능하게 하기 위함)
x_data = np.array(x)
y_data = np.array(y)

# 기울기 a와 절편 b의 값 초기화
a = 0
b = 0

#학습률 정하기
lr = 0.08

# 몇 번 반복될지 설정(0부터 세므로 원하는 반복 횟수에 +1)
epochs = 2001

# MSE 함수
def mse(y, y_hat):
   return ((y - y_hat) ** 2).mean()

mse_older = 0
#경사 하강법 시작
for i in range(epochs):
  y_pred = a * x_data +b
  error = y_data - y_pred
  #오차 함수를 a로 미분한 값
  a_diff = -(1/len(x_data)) * sum(x_data * (error))
  #오차 함수를 b로 미분한 값
  b_diff = -(1/len(x_data)) * sum(y_data - y_pred)

  mse_result =  mse(y_pred, y_data)
  if (mse_result > mse_older):
    if (mse_older == 0):
      mse_older = mse_result
    else:
      lr = lr - 0.01
  else:
    mse_older = mse_result

  if i % 100 == 0:
    print("epoch=%.f, 기울기=%.04f, 절편=%.04f" % (i, a, b))
    print("LR: %.04f, a_diff:%.02f, b_diff:%.02f, MSE:%.10f" % (lr, a_diff, b_diff, mse_result))

  a = a - lr * a_diff
  b = b - lr * b_diff

# 앞서 구한 기울기와 절편을 이용해 그래프를 다시 그리기
y_pred = a * x_data + b
plt.scatter(x, y)
plt.plot([min(x_data), max(x_data)], [min(y_pred), max(y_pred)])
plt.plot([x, (x_data)], [y, (y_pred)])
plt.show()
# Out:
# epoch=0, 기울기=0.0000, 절편=0.0000
# LR: 0.0800, a_diff:-464.00, b_diff:-90.50, MSE:8225.0000000000
# epoch=100, 기울기=7.9221, 절편=45.4498
# LR: 0.0500, a_diff:0.91, b_diff:-5.44, MSE:195.9298445717
# epoch=200, 기울기=4.7911, 절편=64.1345
# LR: 0.0500, a_diff:0.40, b_diff:-2.41, MSE:45.1361486444
# epoch=300, 기울기=3.4037, 절편=72.4133
# LR: 0.0500, a_diff:0.18, b_diff:-1.07, MSE:15.5318017960
# epoch=400, 기울기=2.7891, 절편=76.0815
# LR: 0.0500, a_diff:0.08, b_diff:-0.47, MSE:9.7197726728
# epoch=500, 기울기=2.5167, 절편=77.7069
# LR: 0.0500, a_diff:0.04, b_diff:-0.21, MSE:8.5787347468
# epoch=600, 기울기=2.3960, 절편=78.4270
# LR: 0.0500, a_diff:0.02, b_diff:-0.09, MSE:8.3547221823
# epoch=700, 기울기=2.3425, 절편=78.7461
# LR: 0.0500, a_diff:0.01, b_diff:-0.04, MSE:8.3107432506
# epoch=800, 기울기=2.3188, 절편=78.8875
# LR: 0.0500, a_diff:0.00, b_diff:-0.02, MSE:8.3021091526
# epoch=900, 기울기=2.3084, 절편=78.9502
# LR: 0.0500, a_diff:0.00, b_diff:-0.01, MSE:8.3004140762
# epoch=1000, 기울기=2.3037, 절편=78.9779
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 공부시간 x와 성적 y의 리스트를 만들기
np.random.seed(0);
data = np.random.randint(1, 99, size=(10,2)).tolist()
x = [i[0] for i in data]
y = [i[1] for i in data]

#그래프로 나타내기
plt.figure(figsize=(8,5))
plt.scatter(x,y)
plt.show()

#리스트로 되어 있는 x와 y값을 넘파이 배열로 바꾸기(인덱스를 주어 하나씩 불러와 계산이 가능하게 하기 위함)
x_data = np.array(x)
y_data = np.array(y)

# 기울기 a와 절편 b의 값 초기화
a = 0
b = 0

#학습률 정하기
lr = 0.0002

# 몇 번 반복될지 설정(0부터 세므로 원하는 반복 횟수에 +1)
epochs = 2001

# MSE 함수
def mse(y, y_hat):
   return ((y - y_hat) ** 2).mean()

mse_older = 0
#경사 하강법 시작
for i in range(epochs):
  y_pred = a * x_data +b
  error = y_data - y_pred
  #오차 함수를 a로 미분한 값
  a_diff = -(1/len(x_data)) * sum(x_data * (error))
  #오차 함수를 b로 미분한 값
  b_diff = -(1/len(x_data)) * sum(y_data - y_pred)

  mse_result =  mse(y_pred, y_data)
  if (mse_result > mse_older):
    if (mse_older == 0):
      mse_older = mse_result
    else:
      lr = lr - 0.01
  else:
    mse_older = mse_result

  if i % 100 == 0:
    print("epoch=%.f, 기울기=%.04f, 절편=%.04f" % (i, a, b))
    print("LR: %.04f, a_diff:%.02f, b_diff:%.02f, MSE:%.10f" % (lr, a_diff, b_diff, mse_result))

  a = a - lr * a_diff
  b = b - lr * b_diff

# 앞서 구한 기울기와 절편을 이용해 그래프를 다시 그리기
y_pred = a * x_data + b
plt.scatter(x, y)
plt.plot([min(x_data), max(x_data)], [min(y_pred), max(y_pred)])
plt.plot([x, (x_data)], [y, (y_pred)])
plt.show()
# Out:
# epoch=0, 기울기=0.0000, 절편=0.0000
# LR: 0.0002, a_diff:-3143.70, b_diff:-58.10, MSE:4336.7000000000
# epoch=100, 기울기=0.7916, 절편=0.2122
# LR: 0.0002, a_diff:0.15, b_diff:-9.99, MSE:1833.6937850174
# epoch=200, 기울기=0.7886, 절편=0.4119
# LR: 0.0002, a_diff:0.15, b_diff:-9.98, MSE:1829.7038967702
# epoch=300, 기울기=0.7855, 절편=0.6113
# LR: 0.0002, a_diff:0.15, b_diff:-9.96, MSE:1825.7258858522
# epoch=400, 기울기=0.7825, 절편=0.8105
# LR: 0.0002, a_diff:0.15, b_diff:-9.95, MSE:1821.7597169063
# epoch=500, 기울기=0.7794, 절편=1.0093
# LR: 0.0002, a_diff:0.15, b_diff:-9.93, MSE:1817.8053546806
# epoch=600, 기울기=0.7764, 절편=1.2078
# LR: 0.0002, a_diff:0.15, b_diff:-9.92, MSE:1813.8627640282
# epoch=700, 기울기=0.7734, 절편=1.4061
# LR: 0.0002, a_diff:0.15, b_diff:-9.90, MSE:1809.9319099068
# epoch=800, 기울기=0.7703, 절편=1.6040
# LR: 0.0002, a_diff:0.15, b_diff:-9.89, MSE:1806.0127573784
# epoch=900, 기울기=0.7673, 절편=1.8017
# LR: 0.0002, a_diff:0.15, b_diff:-9.88, MSE:1802.1052716090
# epoch=1000, 기울기=0.7643, 절편=1.9990
# ...
