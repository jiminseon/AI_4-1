# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../content/drive/MyDrive/colab/deeplearning/dataset/pima-indians-diabetes.csv',
                 names = ['pregnant', 'plasma', 'pressure', 'thickness', 'insullin', 'BMI', 'pedigree', 'age', 'class'])
df
# Out:
#      pregnant  plasma  pressure  thickness  insullin   BMI  pedigree  age  \
# 0           6     148        72         35         0  33.6     0.627   50
# 1           1      85        66         29         0  26.6     0.351   31
# 2           8     183        64          0         0  23.3     0.672   32
# 3           1      89        66         23        94  28.1     0.167   21
# 4           0     137        40         35       168  43.1     2.288   33
# ..        ...     ...       ...        ...       ...   ...       ...  ...
# 763        10     101        76         48       180  32.9     0.171   63
# 764         2     122        70         27         0  36.8     0.340   27
# 765         5     121        72         23       112  26.2     0.245   30
# 766         1     126        60          0         0  30.1     0.349   47
# 767         1      93        70         31         0  30.4     0.315   23
#
#      class
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
# ...

# %% [markdown]
# ### 실습과제1

# %%
test = df[['pregnant', 'plasma']]
data1 = test.values


data2 = data1[:5]
print(data2)
print(data2.shape)
print(type(data2))
# Out:
# [[  6 148]
#  [  1  85]
#  [  8 183]
#  [  1  89]
#  [  0 137]]
# (5, 2)
# <class 'numpy.ndarray'>

# %%
x1 = []
y1 = []
for i in range(data2.shape[0]):
  x1.append(data2[i][0])
  y1.append(data2[i][1])
print(x1)
print(y1)
# Out:
# [6, 1, 8, 1, 0]
# [148, 85, 183, 89, 137]

# %%
plt.plot(x1, y1, color='cornflowerblue')
plt.plot(x1, y1, "o", color='blue')
plt.show()

# %% [markdown]
# ## 실습과제 3

# %%
age_mean = round(df.age.mean(),2)
print('Average age:', age_mean)
low_age = df[df['age'] < age_mean]
high_age = df[df['age'] >= age_mean]
# Out:
# Average age: 33.24

# %%
low_age.thickness.plot.hist(bins=50, alpha=0.2)
high_age.thickness.plot.hist(bins=50, alpha=0.5)
plt.legend(['low_age', 'high_age'], loc='upper right')
plt.xlabel('thickness')
plt.show()
