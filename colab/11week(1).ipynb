# %%
import cv2
import math
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import tensorflow as tf
from skimage.transform import resize

count = 0
videoFile = "/content/drive/MyDrive/인공지능/11week/Tom and Jerry.mp4"
cap= cv2.VideoCapture(videoFile)
frameRate = cap.get(5)
x = 1
while(cap.isOpened()):
  frameId = cap.get(1)
  ret, frame = cap.read()
  if (ret != True):
    break
  if (frameId % math.floor(frameRate) == 0):
    filename = "frame%d.jpg" % count
    count += 1
    cv2.imwrite(filename, frame)
cap.release()
print("Done!")
# Out:
# Done!

# %%
count = 0
videoFile = "/content/drive/MyDrive/인공지능/11week/Tom and Jerry 3.mp4"
cap= cv2.VideoCapture(videoFile)
frameRate = cap.get(5)
x = 1
while(cap.isOpened()):
  frameId = cap.get(1)
  ret, frame = cap.read()
  if (ret != True):
    break
  if (frameId % math.floor(frameRate) == 0):
    filename = "test%d.jpg" % count
    count += 1
    cv2.imwrite(filename, frame)
cap.release()
print("Done!")
# Out:
# Done!

# %%
data = pd.read_csv('/content/drive/MyDrive/인공지능/11week/mapping.csv')
test = pd.read_csv('/content/drive/MyDrive/인공지능/11week/testing.csv')

X = []
for img_name in data.Image_ID:
  img = plt.imread('/content/' + img_name)
  X.append(img)
X = np.array(X)

test_image = []
for img_name in test.Image_ID:
  img = plt.imread('/content/' + img_name)
  test_image.append(img)
test_img = np.array(test_image)
from keras.utils import to_categorical
train_y = to_categorical(data.Class)
test_y = to_categorical(test.Class)

image = []
for i in range(0, X.shape[0]):
  a = resize(X[i], preserve_range=True, output_shape=(224, 224, 3)).astype(int)
  image.append(a)
X = np.array(image)

test_image = []
for i in range(0, test_img.shape[0]):
  a = resize(test_img[i], preserve_range=True, output_shape=(224,224)).astype(int)
  test_image.append(a)
test_image = np.array(test_image)

# %%
from keras.applications.vgg16 import preprocess_input
X = preprocess_input(X)
test_image = preprocess_input(test_image)

from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X, train_y, test_size=0.3, random_state=42)

from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.layers import Dense, InputLayer, Dropout

base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

X_train = base_model.predict(X_train)
X_valid = base_model.predict(X_valid)
test_image = base_model.predict(test_image)

X_train = X_train.reshape(208, 7*7*512)
X_valid = X_valid.reshape(90, 7*7*512)
test_image = test_image.reshape(186, 7*7*512)

train = X_train/X_train.max()
X_valid = X_valid/X_valid.max()
test_image = test_image/test_image.max()
print("Done!!")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# 7/7 [==============================] - 114s 16s/step
# 3/3 [==============================] - 52s 17s/step
# 6/6 [==============================] - 103s 17s/step
# Done!!

# %%
model = Sequential()
model.add(InputLayer((7*7*512,)))
model.add(Dense(units = 1024, activation = 'sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(units = 512, activation = 'sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(units = 256, activation = 'sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(3, activation = 'softmax'))

from keras.callbacks import ModelCheckpoint
filepath="weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor = 'val_loss', verbose = 1, save_best_only = True, mode = 'min')

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

history = model.fit(X_train, y_train, epochs = 100, validation_data = (X_valid, y_valid), callbacks = [checkpoint])
print("Done2")
# Out:
# Epoch 1/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4060 - accuracy: 0.3317
# Epoch 1: val_loss improved from inf to 1.10264, saving model to weights.best.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 11s 2s/step - loss: 1.4060 - accuracy: 0.3317 - val_loss: 1.1026 - val_accuracy: 0.3667
# Epoch 2/100
# 7/7 [==============================] - ETA: 0s - loss: 1.0603 - accuracy: 0.5000
# Epoch 2: val_loss did not improve from 1.10264
# 7/7 [==============================] - 3s 451ms/step - loss: 1.0603 - accuracy: 0.5000 - val_loss: 1.1414 - val_accuracy: 0.3889
# Epoch 3/100
# 7/7 [==============================] - ETA: 0s - loss: 1.0052 - accuracy: 0.5337
# Epoch 3: val_loss improved from 1.10264 to 1.09362, saving model to weights.best.hdf5
# 7/7 [==============================] - 4s 625ms/step - loss: 1.0052 - accuracy: 0.5337 - val_loss: 1.0936 - val_accuracy: 0.6111
# Epoch 4/100
# 7/7 [==============================] - ETA: 0s - loss: 0.8207 - accuracy: 0.6250
# Epoch 4: val_loss improved from 1.09362 to 1.04505, saving model to weights.best.hdf5
# 7/7 [==============================] - 6s 908ms/step - loss: 0.8207 - accuracy: 0.6250 - val_loss: 1.0450 - val_accuracy: 0.3667
# Epoch 5/100
# 7/7 [==============================] - ETA: 0s - loss: 0.7396 - accuracy: 0.6635
# Epoch 5: val_loss did not improve from 1.04505
# 7/7 [==============================] - 3s 450ms/step - loss: 0.7396 - accuracy: 0.6635 - val_loss: 1.0517 - val_accuracy: 0.6444
# Epoch 6/100
# 7/7 [==============================] - ETA: 0s - loss: 0.6026 - accuracy: 0.7356
# Epoch 6: val_loss did not improve from 1.04505
# 7/7 [==============================] - 3s 445ms/step - loss: 0.6026 - accuracy: 0.7356 - val_loss: 1.0663 - val_accuracy: 0.3667
# Epoch 7/100
# 7/7 [==============================] - ETA: 0s - loss: 0.5239 - accuracy: 0.7885
# Epoch 7: val_loss improved from 1.04505 to 0.92204, saving model to weights.best.hdf5
# 7/7 [==============================] - 4s 616ms/step - loss: 0.5239 - accuracy: 0.7885 - val_loss: 0.9220 - val_accuracy: 0.6222
# Epoch 8/100
# 7/7 [==============================] - ETA: 0s - loss: 0.4217 - accuracy: 0.8606
# Epoch 8: val_loss did not improve from 0.92204
# 7/7 [==============================] - 12s 2s/step - loss: 0.4217 - accuracy: 0.8606 - val_loss: 1.1065 - val_accuracy: 0.4222
# Epoch 9/100
# 7/7 [==============================] - ETA: 0s - loss: 0.3876 - accuracy: 0.8702
# Epoch 9: val_loss did not improve from 0.92204
# 7/7 [==============================] - 3s 481ms/step - loss: 0.3876 - accuracy: 0.8702 - val_loss: 0.9371 - val_accuracy: 0.5222
# Epoch 10/100
# 7/7 [==============================] - ETA: 0s - loss: 0.3267 - accuracy: 0.8750
# Epoch 10: val_loss did not improve from 0.92204
# 7/7 [==============================] - 3s 473ms/step - loss: 0.3267 - accuracy: 0.8750 - val_loss: 1.0335 - val_accuracy: 0.4556
# Epoch 11/100
# 7/7 [==============================] - ETA: 0s - loss: 0.3105 - accuracy: 0.8846
# Epoch 11: val_loss did not improve from 0.92204
# 7/7 [==============================] - 5s 755ms/step - loss: 0.3105 - accuracy: 0.8846 - val_loss: 1.0630 - val_accuracy: 0.4556
# Epoch 12/100
# 7/7 [==============================] - ETA: 0s - loss: 0.2556 - accuracy: 0.9327
# Epoch 12: val_loss improved from 0.92204 to 0.80559, saving model to weights.best.hdf5
# 7/7 [==============================] - 6s 678ms/step - loss: 0.2556 - accuracy: 0.9327 - val_loss: 0.8056 - val_accuracy: 0.6333
# Epoch 13/100
# 7/7 [==============================] - ETA: 0s - loss: 0.2200 - accuracy: 0.9327
# Epoch 13: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 470ms/step - loss: 0.2200 - accuracy: 0.9327 - val_loss: 1.1016 - val_accuracy: 0.4444
# Epoch 14/100
# 7/7 [==============================] - ETA: 0s - loss: 0.1814 - accuracy: 0.9567
# Epoch 14: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 511ms/step - loss: 0.1814 - accuracy: 0.9567 - val_loss: 0.9520 - val_accuracy: 0.4889
# Epoch 15/100
# 7/7 [==============================] - ETA: 0s - loss: 0.
100
# 7/7 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9615
# Epoch 31: val_loss did not improve from 0.80559
# 7/7 [==============================] - 4s 597ms/step - loss: 0.1049 - accuracy: 0.9615 - val_loss: 1.1356 - val_accuracy: 0.4889
# Epoch 32/100
# 7/7 [==============================] - ETA: 0s - loss: 0.1258 - accuracy: 0.9471
# Epoch 32: val_loss did not improve from 0.80559
# 7/7 [==============================] - 5s 653ms/step - loss: 0.1258 - accuracy: 0.9471 - val_loss: 1.0553 - val_accuracy: 0.5444
# Epoch 33/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0922 - accuracy: 0.9712
# Epoch 33: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 456ms/step - loss: 0.0922 - accuracy: 0.9712 - val_loss: 0.9578 - val_accuracy: 0.6889
# Epoch 34/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9615
# Epoch 34: val_loss did not improve from 0.80559
# 7/7 [==============================] - 4s 552ms/step - loss: 0.0844 - accuracy: 0.9615 - val_loss: 1.0464 - val_accuracy: 0.5444
# Epoch 35/100
# 7/7 [==============================] - ETA: 0s - loss: 0.1050 - accuracy: 0.9615
# Epoch 35: val_loss did not improve from 0.80559
# 7/7 [==============================] - 6s 807ms/step - loss: 0.1050 - accuracy: 0.9615 - val_loss: 1.2419 - val_accuracy: 0.4889
# Epoch 36/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.9760
# Epoch 36: val_loss did not improve from 0.80559
# 7/7 [==============================] - 5s 648ms/step - loss: 0.0673 - accuracy: 0.9760 - val_loss: 1.2978 - val_accuracy: 0.4889
# Epoch 37/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0978 - accuracy: 0.9663
# Epoch 37: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 456ms/step - loss: 0.0978 - accuracy: 0.9663 - val_loss: 1.1458 - val_accuracy: 0.5889
# Epoch 38/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0795 - accuracy: 0.9712
# Epoch 38: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 457ms/step - loss: 0.0795 - accuracy: 0.9712 - val_loss: 1.5608 - val_accuracy: 0.4444
# Epoch 39/100
# 7/7 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.9519
# Epoch 39: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 510ms/step - loss: 0.1205 - accuracy: 0.9519 - val_loss: 0.9411 - val_accuracy: 0.7000
# Epoch 40/100
# 7/7 [==============================] - ETA: 0s - loss: 0.1274 - accuracy: 0.9567
# Epoch 40: val_loss did not improve from 0.80559
# 7/7 [==============================] - 5s 701ms/step - loss: 0.1274 - accuracy: 0.9567 - val_loss: 1.0779 - val_accuracy: 0.6444
# Epoch 41/100
# 7/7 [==============================] - ETA: 0s - loss: 0.1111 - accuracy: 0.9663
# Epoch 41: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 456ms/step - loss: 0.1111 - accuracy: 0.9663 - val_loss: 1.2808 - val_accuracy: 0.4556
# Epoch 42/100
# 7/7 [==============================] - ETA: 0s - loss: 0.1147 - accuracy: 0.9615
# Epoch 42: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 461ms/step - loss: 0.1147 - accuracy: 0.9615 - val_loss: 0.9648 - val_accuracy: 0.6667
# Epoch 43/100
# 7/7 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9423
# Epoch 43: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 457ms/step - loss: 0.1037 - accuracy: 0.9423 - val_loss: 1.1971 - val_accuracy: 0.5111
# Epoch 44/100
# 7/7 [==============================] - ETA: 0s - loss: 0.1141 - accuracy: 0.9615
# Epoch 44: val_loss did not improve from 0.80559
# 7/7 [==============================] - 5s 754ms/step - loss: 0.1141 - accuracy: 0.9615 - val_loss: 1.3138 - val_accuracy: 0.5444
# Epoch 45/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0925 - accuracy: 0.9663
# Epoch 45: val_loss did not improve from 0.80559
# 7/7 [==============================] - 4s 473ms/step - loss: 0.0925 - accuracy: 0.9663 - val_loss: 1.0671 - val_accuracy: 0.7000
# Epoch 46/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0991 - accuracy: 0.
100
# 7/7 [==============================] - ETA: 0s - loss: 0.0781 - accuracy: 0.9663
# Epoch 61: val_loss did not improve from 0.80559
# 7/7 [==============================] - 5s 747ms/step - loss: 0.0781 - accuracy: 0.9663 - val_loss: 1.0287 - val_accuracy: 0.6778
# Epoch 62/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0563 - accuracy: 0.9808
# Epoch 62: val_loss did not improve from 0.80559
# 7/7 [==============================] - 4s 472ms/step - loss: 0.0563 - accuracy: 0.9808 - val_loss: 1.1031 - val_accuracy: 0.6222
# Epoch 63/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.9567
# Epoch 63: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 458ms/step - loss: 0.0819 - accuracy: 0.9567 - val_loss: 1.2720 - val_accuracy: 0.5778
# Epoch 64/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0906 - accuracy: 0.9615
# Epoch 64: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 456ms/step - loss: 0.0906 - accuracy: 0.9615 - val_loss: 1.0759 - val_accuracy: 0.7111
# Epoch 65/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.9760
# Epoch 65: val_loss did not improve from 0.80559
# 7/7 [==============================] - 4s 676ms/step - loss: 0.0574 - accuracy: 0.9760 - val_loss: 1.2859 - val_accuracy: 0.6111
# Epoch 66/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9567
# Epoch 66: val_loss did not improve from 0.80559
# 7/7 [==============================] - 4s 587ms/step - loss: 0.0939 - accuracy: 0.9567 - val_loss: 1.6272 - val_accuracy: 0.5000
# Epoch 67/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9808
# Epoch 67: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 464ms/step - loss: 0.0621 - accuracy: 0.9808 - val_loss: 1.2740 - val_accuracy: 0.6889
# Epoch 68/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0778 - accuracy: 0.9712
# Epoch 68: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 457ms/step - loss: 0.0778 - accuracy: 0.9712 - val_loss: 1.0183 - val_accuracy: 0.6111
# Epoch 69/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0856 - accuracy: 0.9760
# Epoch 69: val_loss did not improve from 0.80559
# 7/7 [==============================] - 4s 577ms/step - loss: 0.0856 - accuracy: 0.9760 - val_loss: 1.3225 - val_accuracy: 0.5556
# Epoch 70/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0821 - accuracy: 0.9712
# Epoch 70: val_loss did not improve from 0.80559
# 7/7 [==============================] - 5s 677ms/step - loss: 0.0821 - accuracy: 0.9712 - val_loss: 1.2577 - val_accuracy: 0.6889
# Epoch 71/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9808
# Epoch 71: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 454ms/step - loss: 0.0504 - accuracy: 0.9808 - val_loss: 1.1805 - val_accuracy: 0.7111
# Epoch 72/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0722 - accuracy: 0.9663
# Epoch 72: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 456ms/step - loss: 0.0722 - accuracy: 0.9663 - val_loss: 1.4301 - val_accuracy: 0.5556
# Epoch 73/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0704 - accuracy: 0.9712
# Epoch 73: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 494ms/step - loss: 0.0704 - accuracy: 0.9712 - val_loss: 1.1466 - val_accuracy: 0.6889
# Epoch 74/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0975 - accuracy: 0.9567
# Epoch 74: val_loss did not improve from 0.80559
# 7/7 [==============================] - 5s 758ms/step - loss: 0.0975 - accuracy: 0.9567 - val_loss: 1.0978 - val_accuracy: 0.6778
# Epoch 75/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0969 - accuracy: 0.9567
# Epoch 75: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 459ms/step - loss: 0.0969 - accuracy: 0.9567 - val_loss: 1.3255 - val_accuracy: 0.6556
# Epoch 76/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9663
# Epoch 76: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 458ms/step - loss: 0.0845 - accuracy: 0.9663 - val_loss: 1.1187 - val_accuracy: 0.6222
# Epoch 77/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9808
# Epoch 77: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 467ms/step - loss: 0.0637 - accuracy: 0.9808 - val_loss: 0.9816 - val_accuracy: 0.7111
# Epoch 78/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0816 - accuracy: 0.9663
# Epoch 78: val_loss did not improve from 0.80559
# 7/7 [==============================] - 5s 728ms/step - loss: 0.0816 - accuracy: 0.9663 - val_loss: 1.2267 - val_accuracy: 0.6778
# Epoch 79/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0713 - accuracy: 0.9663
# Epoch 79: val_loss did not improve from 0.80559
# 7/7 [==============================] - 4s 520ms/step - loss: 0.0713 - accuracy: 0.9663 - val_loss: 1.3057 - val_accuracy: 0.6778
# Epoch 80/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9808
# Epoch 80: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 459ms/step - loss: 0.0487 - accuracy: 0.9808 - val_loss: 1.1446 - val_accuracy: 0.6889
# Epoch 81/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0635 - accuracy: 0.9760
# Epoch 81: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 456ms/step - loss: 0.0635 - accuracy: 0.9760 - val_loss: 1.1198 - val_accuracy: 0.6889
# Epoch 82/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0871 - accuracy: 0.9663
# Epoch 82: val_loss did not improve from 0.80559
# 7/7 [==============================] - 4s 621ms/step - loss: 0.0871 - accuracy: 0.9663 - val_loss: 1.2514 - val_accuracy: 0.5444
# Epoch 83/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.9663
# Epoch 83: val_loss did not improve from 0.80559
# 7/7 [==============================] - 5s 636ms/step - loss: 0.0767 - accuracy: 0.9663 - val_loss: 1.1519 - val_accuracy: 0.6889
# Epoch 84/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0759 - accuracy: 0.9663
# Epoch 84: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 457ms/step - loss: 0.0759 - accuracy: 0.9663 - val_loss: 1.4047 - val_accuracy: 0.6889
# Epoch 85/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9760
# Epoch 85: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 466ms/step - loss: 0.0593 - accuracy: 0.9760 - val_loss: 1.4005 - val_accuracy: 0.6889
# Epoch 86/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0382 - accuracy: 0.9856
# Epoch 86: val_loss did not improve from 0.80559
# 7/7 [==============================] - 4s 550ms/step - loss: 0.0382 - accuracy: 0.9856 - val_loss: 1.1510 - val_accuracy: 0.6889
# Epoch 87/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0777 - accuracy: 0.9712
# Epoch 87: val_loss did not improve from 0.80559
# 7/7 [==============================] - 5s 714ms/step - loss: 0.0777 - accuracy: 0.9712 - val_loss: 1.1457 - val_accuracy: 0.6889
# Epoch 88/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0654 - accuracy: 0.9808
# Epoch 88: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 459ms/step - loss: 0.0654 - accuracy: 0.9808 - val_loss: 1.0471 - val_accuracy: 0.7111
# Epoch 89/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0731 - accuracy: 0.9712
# Epoch 89: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 457ms/step - loss: 0.0731 - accuracy: 0.9712 - val_loss: 1.0312 - val_accuracy: 0.7111
# Epoch 90/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 0.9663
# Epoch 90: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 466ms/step - loss: 0.0532 - accuracy: 0.9663 - val_loss: 1.3250 - val_accuracy: 0.5889
# Epoch 91/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0726 - accuracy: 0.9712
# Epoch 91: val_loss did not improve from 0.80559
# 7/7 [==============================] - 5s 739ms/step - loss: 0.0726 - accuracy: 0.9712 - val_loss: 1.2763 - val_accuracy: 0.6778
# Epoch 92/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9808
# Epoch 92: val_loss did not improve from 0.80559
# 7/7 [==============================] - 4s 460ms/step - loss: 0.0820 - accuracy: 0.9808 - val_loss: 1.2205 - val_accuracy: 0.6889
# Epoch 93/100
# 7/7 [==============================] - ETA: 0s - loss: 0.1014 - accuracy: 0.9663
# Epoch 93: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 460ms/step - loss: 0.1014 - accuracy: 0.9663 - val_loss: 1.3834 - val_accuracy: 0.6222
# Epoch 94/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0790 - accuracy: 0.9663
# Epoch 94: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 459ms/step - loss: 0.0790 - accuracy: 0.9663 - val_loss: 1.2751 - val_accuracy: 0.6778
# Epoch 95/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0928 - accuracy: 0.9615
# Epoch 95: val_loss did not improve from 0.80559
# 7/7 [==============================] - 5s 709ms/step - loss: 0.0928 - accuracy: 0.9615 - val_loss: 1.2465 - val_accuracy: 0.7222
# Epoch 96/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0721 - accuracy: 0.9808
# Epoch 96: val_loss did not improve from 0.80559
# 7/7 [==============================] - 4s 546ms/step - loss: 0.0721 - accuracy: 0.9808 - val_loss: 1.1556 - val_accuracy: 0.7222
# Epoch 97/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0538 - accuracy: 0.9808
# Epoch 97: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 459ms/step - loss: 0.0538 - accuracy: 0.9808 - val_loss: 1.0752 - val_accuracy: 0.7000
# Epoch 98/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0859 - accuracy: 0.9663
# Epoch 98: val_loss did not improve from 0.80559
# 7/7 [==============================] - 3s 461ms/step - loss: 0.0859 - accuracy: 0.9663 - val_loss: 1.2630 - val_accuracy: 0.6889
# Epoch 99/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0629 - accuracy: 0.9760
# Epoch 99: val_loss did not improve from 0.80559
# 7/7 [==============================] - 4s 627ms/step - loss: 0.0629 - accuracy: 0.9760 - val_loss: 1.5292 - val_accuracy: 0.6778
# Epoch 100/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0976 - accuracy: 0.9663
# Epoch 100: val_loss did not improve from 0.80559
# 7/7 [==============================] - 5s 642ms/step - loss: 0.0976 - accuracy: 0.9663 - val_loss: 1.5543 - val_accuracy: 0.6444
# Done2

# %%
scores = model.evaluate(test_image, test_y)
print("Real Test %s: %.2f%%" % (model.metrics_names[1], scores[1] * 100))

predictions = np.argmax(model.predict(test_image), axis = 1)
print("The screen time of None is ", predictions[predictions == 0].shape[0], "seconds")
print("The screen time of Jerry is ", predictions[predictions == 1].shape[0], "seconds")
print("The screen time of Tom is ", predictions[predictions == 2].shape[0], "seconds")

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))
plt.plot(x_len, acc, marker = '.', c = 'red', label = 'Trainset_acc')
plt.plot(x_len, val_acc, marker = '.', c = 'lightcoral', label = 'Testset_acc')
plt.plot(x_len, y_vloss, marker = '.', c = 'cornflowerblue', label = 'Testset_loss')
plt.plot(x_len, y_loss, marker = '.', c = 'blue', label = 'Trainset_loss')

plt.legend(loc = 'upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss/acc')
plt.show()
# Out:
# 6/6 [==============================] - 0s 77ms/step - loss: 3.4864 - accuracy: 0.1559
# Real Test accuracy: 15.59%
# 6/6 [==============================] - 1s 80ms/step
# The screen time of None is  183 seconds
# The screen time of Jerry is  0 seconds
# The screen time of Tom is  3 seconds
